# %%
#import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.linear_model import LogisticRegression,Lasso,LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.externals import joblib
from sklearn.decomposition import PCA
from scipy.stats import zscore
from sklearn.model_selection import cross_val_score

# %%
#fetching data into variable
df = pd.read_csv("C:\\Users\\Data Sets\\Projects\\avocado.csv")
df.head()
# Out:
#    index        Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  \
# 0      0  12/27/2015          1.33      64236.62   1036.74   54454.85
# 1      1  12/20/2015          1.35      54876.98    674.28   44638.81
# 2      2  12/13/2015          0.93     118220.22    794.70  109149.67
# 3      3   12/6/2015          1.08      78992.15   1132.00   71976.41
# 4      4  11/29/2015          1.28      51039.60    941.48   43838.39
#
#    PLU_4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0     48.16     8696.87     8603.62       93.25          0.0  conventional
# 1     58.33     9505.56     9408.07       97.49          0.0  conventional
# 2    130.50     8145.35     8042.21      103.14          0.0  conventional
# 3     72.58     5811.16     5677.40      133.76          0.0  conventional
# 4     75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
#as we drop index column beacuse it just kind of id which have no effect on dataset
df.drop('index',inplace=True,axis=1)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0  12/27/2015          1.33      64236.62   1036.74   54454.85     48.16
# 1  12/20/2015          1.35      54876.98    674.28   44638.81     58.33
# 2  12/13/2015          0.93     118220.22    794.70  109149.67    130.50
# 3   12/6/2015          1.08      78992.15   1132.00   71976.41     72.58
# 4  11/29/2015          1.28      51039.60    941.48   43838.39     75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
#checking the total rows and total columns
df.shape
# Out:
# (18249, 13)

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', 'PLU_4046', 'PLU_4225',
#        'PLU_4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags',
#        'type', 'year', 'region'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# PLU_4046        float64
# PLU_4225        float64
# PLU_4770        float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
#Extract the Month from DOB into separate column
df['Month'] = pd.DatetimeIndex(df['Date']).month
df.head()
# Out:
#          Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0  12/27/2015          1.33      64236.62   1036.74   54454.85     48.16
# 1  12/20/2015          1.35      54876.98    674.28   44638.81     58.33
# 2  12/13/2015          0.93     118220.22    794.70  109149.67    130.50
# 3   12/6/2015          1.08      78992.15   1132.00   71976.41     72.58
# 4  11/29/2015          1.28      51039.60    941.48   43838.39     75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month
# 0  Albany     12
# 1  Albany     12
# 2  Albany     12
# 3  Albany     12
# 4  Albany     11

# %%
#Extract the Date from DOB into separate column
df['Date'] = pd.DatetimeIndex(df['Date']).day
df.head()
# Out:
#    Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0    27          1.33      64236.62   1036.74   54454.85     48.16
# 1    20          1.35      54876.98    674.28   44638.81     58.33
# 2    13          0.93     118220.22    794.70  109149.67    130.50
# 3     6          1.08      78992.15   1132.00   71976.41     72.58
# 4    29          1.28      51039.60    941.48   43838.39     75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month
# 0  Albany     12
# 1  Albany     12
# 2  Albany     12
# 3  Albany     12
# 4  Albany     11

# %%
#checking the value counts of each date
df.Date.value_counts()
# Out:
# 4     756
# 11    756
# 18    755
# 25    755
# 8     648
# 10    648
# 19    648
# 5     648
# 22    648
# 15    648
# 24    648
# 17    648
# 26    648
# 12    648
# 1     648
# 3     648
# 27    540
# 28    540
# 7     540
# 13    540
# 21    540
# 29    540
# 20    540
# 14    540
# 6     539
# 2     432
# 31    432
# 23    432
# 9     432
# 30    432
# 16    432
# Name: Date, dtype: int64

# %%
#checking the value counts of each type
df.type.value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
#co relation of total volume to total bag
df[['Total Volume','Total Bags']].corr()
# Out:
#               Total Volume  Total Bags
# Total Volume      1.000000    0.963047
# Total Bags        0.963047    1.000000

# %%
#checking the average year of volume of avacado per year
df.groupby('year')['Total Volume'].mean()
# Out:
# year
# 2015    7.810274e+05
# 2016    8.584206e+05
# 2017    8.623393e+05
# 2018    1.066928e+06
# Name: Total Volume, dtype: float64

# %%
#checking the organic type of avacado 
organic = df[df['type'] == 'organic']
organic
# Out:
#        Date  AveragePrice  Total Volume  PLU_4046  PLU_4225  PLU_4770  \
# 9126     27          1.83        989.55      8.16     88.59      0.00
# 9127     20          1.89       1163.03     30.24    172.14      0.00
# 9128     13          1.85        995.96     10.44    178.70      0.00
# 9129      6          1.84       1158.42     90.29    104.18      0.00
# 9130     29          1.94        831.69      0.00     94.73      0.00
# ...     ...           ...           ...       ...       ...       ...
# 18244     4          1.63      17074.83   2046.96   1529.20      0.00
# 18245    28          1.71      13888.04   1191.70   3431.50      0.00
# 18246    21          1.87      13766.76   1191.92   2452.79    727.94
# 18247    14          1.93      16205.22   1527.63   2981.04    727.01
# 18248     7          1.62      17489.58   2894.77   2356.13    224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9126       892.80      892.80        0.00          0.0  organic  2015
# 9127       960.65      960.65        0.00          0.0  organic  2015
# 9128       806.82      806.82        0.00          0.0  organic  2015
# 9129       963.95      948.52       15.43          0.0  organic  2015
# 9130       736.96      736.96        0.00          0.0  organic  2015
# ...           ...         ...         ...          ...      ...   ...
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region  Month
# 9126             Albany     12
# 9127             Albany     12
# 9128             Albany     12
# 9129             Albany     12
# 9130             Albany     11
# ...                 ...    ...
# 18244  WestTexNewMexico      2
# 18245  WestTexNewMexico      1
# 18246  WestTexNewMexico      1
# 18247  WestTexNewMexico      1
# 18248  WestTexNewMexico      1
#
# [9123 rows x 14 columns]

# %%
#checking the mean of price at each year of organic type of avacado
organic.groupby('year')['AveragePrice'].mean()
# Out:
# year
# 2015    1.673324
# 2016    1.571684
# 2017    1.735521
# 2018    1.567176
# Name: AveragePrice, dtype: float64

# %%
#finding how much type of avacado is sell in last 4 year
df.groupby('year')['type'].value_counts()
# Out:
# year  type
# 2015  conventional    2808
#       organic         2807
# 2016  conventional    2808
#       organic         2808
# 2017  conventional    2862
#       organic         2860
# 2018  conventional     648
#       organic          648
# Name: type, dtype: int64

# %%
#total no of sale in each year of  4 years
df.groupby('year')['Total Volume'].count()
# Out:
# year
# 2015    5615
# 2016    5616
# 2017    5722
# 2018    1296
# Name: Total Volume, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  int64
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   PLU_4046      18249 non-null  float64
#  4   PLU_4225      18249 non-null  float64
#  5   PLU_4770      18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
#  13  Month         18249 non-null  int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
#checking null values using heatmap
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#                Date  AveragePrice  Total Volume      PLU_4046      PLU_4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      15.662612      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std        8.776281      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        1.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%        8.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       16.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       23.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       31.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#            PLU_4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year         Month
# count  18249.000000  18249.000000
# mean    2016.147899      6.177215
# std        0.939938      3.534130
# min     2015.000000      1.000000
# 25%     2015.000000      3.000000
# 50%     2016.000000      6.000000
# 75%     2017.000000      9.000000
# max     2018.000000     12.000000

# %% [markdown]
# Above statatics data show that there multiple outliers mostly in XLargeBags
# There is also difference between mean and 50% value in some of the columns which used to get fix for better prediction

# %%
#checking ratio of year and price that which year had max average price
sns.barplot(x = "year" , y = "AveragePrice" ,data=df )

# %% [markdown]
# so above graph showing that 2017 year is that yera where max average price is there

# %%
#checking ratio of month and price that which year had max average price
sns.barplot(x = "Month" , y = "AveragePrice" ,data=df )

# %% [markdown]
# sept and october is the month where max no og average price is there

# %%
sns.lineplot(x = 'year', y = 'AveragePrice', data=df)

# %%
#checking ratio of type and price that which year had max average price
sns.barplot(x = "type" , y = "AveragePrice" ,data=df )

# %% [markdown]
# #As organic type of avacado is having the more price per unit then conventional

# %%
plt.figure(figsize=(16,10))
sns.lineplot(x="Month", y="AveragePrice", hue='type', data=df)
plt.show()

# %% [markdown]
# Above graph shown that there is hike between month 8-10 of both type of avacado

# %%
plt.figure(figsize=(24,15))
sns.barplot(x='region',y='AveragePrice',data=df)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('ration of Price and Region')
# Out:
# Text(0.5, 1.0, 'ration of Price and Region')

# %% [markdown]
# above graph is showing that HartfordSpringfield ,SanFrancisco and  NewYork are having more average price as compared to other region

# %%
date=df.groupby('Date').mean()
plt.figure(figsize=(12,10))
date['AveragePrice'].plot()
plt.title('Average_Price')
# Out:
# Text(0.5, 1.0, 'Average_Price')

# %% [markdown]
# above is showing on date 28,29 and 30 the price of avacado is high

# %%
month=df.groupby('Month').mean()
plt.figure(figsize=(12,10))
month['AveragePrice'].plot()
plt.title('Average_Price')
# Out:
# Text(0.5, 1.0, 'Average_Price')

# %% [markdown]
# in between august to october the price of avacado is much higher as comapared to other months

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
df.hist(figsize=(20,20), grid = True, layout = (4,4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDAB7248>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDB17C88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDD811C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDDB7F08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDDF0D88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDE29C48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDE64A48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDE9F788>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDE9F988>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDED7908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDF4D488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDF84288>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBDFB8FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBE381F48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBE3BCF88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CBE3F5F08>]],
#       dtype=object)

# %%
df['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
#Making the categorical data into numercial for better EDA
column = ['type','region']
le = LabelEncoder()
for i in column:
    df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# Date              int64
# AveragePrice    float64
# Total Volume    float64
# PLU_4046        float64
# PLU_4225        float64
# PLU_4770        float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int32
# year              int64
# region            int32
# Month             int64
# dtype: object

# %%
df.head()
# Out:
#    Date  AveragePrice  Total Volume  PLU_4046   PLU_4225  PLU_4770  \
# 0    27          1.33     11.070344  6.944801  10.905146  3.895080
# 1    20          1.35     10.912867  6.515127  10.706381  4.083115
# 2    13          0.93     11.680313  6.679222  11.600485  4.879007
# 3     6          1.08     11.277116  7.032624  11.184108  4.298373
# 4    29          1.28     10.840377  6.848515  10.688288  4.340944
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region  Month
# 0    9.070833    9.060055    4.545951          0.0     0  2015       0     12
# 1    9.159737    9.149429    4.589955          0.0     0  2015       0     12
# 2    9.005325    8.992584    4.645736          0.0     0  2015       0     12
# 3    8.667708    8.644425    4.903495          0.0     0  2015       0     12
# 4    8.729874    8.697389    5.291746          0.0     0  2015       0     11

# %%
df.type  =df.type.astype(float)

# %%
#plotting the boxplot of each column to check the outliers 
df.plot(kind='box',subplots = True,layout=(4,5),figsize = (15,10))
# Out:
# Date                AxesSubplot(0.125,0.71587;0.133621x0.16413)
# AveragePrice     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Volume      AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# PLU_4046         AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# PLU_4225         AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# PLU_4770           AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Total Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Small Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Large Bags      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# type               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# year            AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# region           AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Month           AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %%
#calculate the zscore
z = np.abs(zscore(df))
print(z)
# Out:
# [[1.28930873 0.19535234 0.06196232 ... 1.21001338 1.68655445 1.64461178]
#  [0.49165249 0.1435096  0.13430157 ... 1.21001338 1.68655445 1.64461178]
#  [0.30600376 1.2322071  0.21823548 ... 1.21001338 1.68655445 1.64461178]
#  ...
#  [0.60560338 1.20440158 0.76950251 ... 1.98075592 1.47810526 1.46287832]
#  [0.19205286 1.35992979 0.69459605 ... 1.98075592 1.47810526 1.46287832]
#  [0.98970911 0.55636736 0.65956156 ... 1.98075592 1.47810526 1.46287832]]

# %%
#checking the co-relation of all column to each other
df_cor = df.corr()
plt.figure(figsize=(30,25))
sns.heatmap(df_cor,annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# as year is most negative co related column among all columns and also the difference is very close of each column

# %%
threshold = 3
print(np.where(z<3))
print(df.shape)
# Out:
# (array([    0,     0,     0, ..., 17650, 17650, 17650], dtype=int64), array([ 0,  1,  2, ..., 11, 12, 13], dtype=int64))
# (17651, 14)

# %%
#Assign the value to df_new which are less the threshold value and removing the outliers
df_new = df[(z<3).all(axis = 1)]

# %%
print(df.shape)
print(df_new.shape)
df = df_new
print('Shape after removing outlires',df.shape)
# Out:
# (17651, 14)
# (17525, 14)
# Shape after removing outlires (17525, 14)

# %%
#now finding the mean value of each column 
print(df['PLU_4225'].mean())
print(df['Total Bags'].mean())
print(df['Small Bags'].mean())
# Out:
# 9.789177838993517
# 10.121796496615035
# 9.737532146999834

# %%
#replace the outlier value to its mean value to remove outliers
df.loc[df['PLU_4225']<3,'PLU_4225'] = np.mean(df['PLU_4225'])
df.loc[df['Total Bags']<4.8,'Total Bags'] = np.mean(df['Total Bags'])
df.loc[df['Small Bags']<4,'Small Bags'] = np.mean(df['Small Bags'])

# %%
#plotting the boxplot of each column to check the outliers 
df.plot(kind='box',subplots = True,layout=(4,5),figsize = (15,10))
# Out:
# Date                AxesSubplot(0.125,0.71587;0.133621x0.16413)
# AveragePrice     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Total Volume      AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# PLU_4046         AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# PLU_4225         AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# PLU_4770           AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Total Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Small Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# Large Bags      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# type               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# year            AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# region           AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# Month           AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %% [markdown]
# Now there are no outliers in the data set after removing it through mean value

# %%
print(df.shape)
print(df_new.shape)
df = df_new
print('Shape after removing outlires',df.shape)
# Out:
# (17525, 14)
# (17525, 14)
# Shape after removing outlires (17525, 14)

# %%
df.skew()
# Out:
# Date            0.012943
# AveragePrice    0.350548
# Total Volume   -0.058010
# PLU_4046       -0.426890
# PLU_4225       -0.419363
# PLU_4770        0.056523
# Total Bags     -0.233833
# Small Bags     -0.315340
# Large Bags     -0.617846
# XLarge Bags     1.205366
# type           -0.023627
# year            0.229681
# region          0.036655
# Month           0.108797
# dtype: float64

# %%
#making the skew less than or equal to 0.55 for better prediction and plotting Normal distribution
skew=('Total Volume','PLU_4046','PLU_4225','PLU_4770','Total Bags','Small Bags','Large Bags','XLarge Bags')
for col in skew :
    if df.skew().loc[col]>0.55:
        df[col] = np.log1p(df[col])

# %%
df.skew()
# Out:
# Date            0.012943
# AveragePrice    0.350548
# Total Volume   -0.058010
# PLU_4046       -0.426890
# PLU_4225       -0.419363
# PLU_4770        0.056523
# Total Bags     -0.233833
# Small Bags     -0.315340
# Large Bags     -0.617846
# XLarge Bags     0.900621
# type           -0.023627
# year            0.229681
# region          0.036655
# Month           0.108797
# dtype: float64

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
df.hist(figsize=(20,20), grid = True, layout = (4,4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC0DA3708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC2B39308>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC2B5DA08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC2B91F88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC2BCD788>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4A83FC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4ABCDC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4AF5B08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4AF5D08>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4B2FC88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4BA1808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4EBD608>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4EF6488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4F2E348>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4F661C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000024CC4FA0148>]],
#       dtype=object)

# %% [markdown]
# average price, total bags and total volume is well normally distributed data among all column

# %%
#assign the value of x and y for training and testing phase
x = df.drop(columns=['AveragePrice','Date'])
y = df[["AveragePrice"]]
print(x.shape)
print(y.shape)
# Out:
# (17525, 12)
# (17525, 1)

# %% [markdown]
# Above we are using AveragePrice as output variable and used to do the prediction

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x)
x = pd.DataFrame(x,columns=x.columns)

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeRegressor(),KNeighborsRegressor(),AdaBoostRegressor(),LinearRegression(),GradientBoostingRegressor()]
max_r2_score = 0
for r_state in range(40,90):
    train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = r_state,test_size = 0.33)
    for i in model:
        i.fit(train_x,train_y)
        pre = i.predict(test_x)
        r2_sc = r2_score(test_y,pre)
        print("R2 score correspond to random state " ,r_state ,"is", r2_sc)
        if r2_sc> max_r2_score:
            max_r2_score=r2_sc
            final_state = r_state
            final_model = i
            
print()
print()
print()
print()
print("max R2 score correspond to random state " ,final_state , "is" , max_r2_score ,"and model is",final_model)
# Out:
# R2 score correspond to random state  40 is 0.7512976965574156
# R2 score correspond to random state  40 is 0.8397581523309288
# R2 score correspond to random state  40 is 0.558074016266051
# R2 score correspond to random state  40 is 0.5220004961198879
# R2 score correspond to random state  40 is 0.7366921362634195
# R2 score correspond to random state  41 is 0.7259534156287951
# R2 score correspond to random state  41 is 0.8414377218379625
# R2 score correspond to random state  41 is 0.5391585677896671
# R2 score correspond to random state  41 is 0.5237919681842536
# R2 score correspond to random state  41 is 0.7403602424533802
# R2 score correspond to random state  42 is 0.7497574676662415
# R2 score correspond to random state  42 is 0.8410299518813924
# R2 score correspond to random state  42 is 0.5541115807997941
# R2 score correspond to random state  42 is 0.5321637705162396
# R2 score correspond to random state  42 is 0.7305661379670931
# R2 score correspond to random state  43 is 0.7655380377676442
# R2 score correspond to random state  43 is 0.8456301815025519
# R2 score correspond to random state  43 is 0.5683472192564969
# R2 score correspond to random state  43 is 0.5411081332372798
# R2 score correspond to random state  43 is 0.7481585394124404
# R2 score correspond to random state  44 is 0.722261707758081
# R2 score correspond to random state  44 is 0.8357264899236997
# R2 score correspond to random state  44 is 0.5489470306085794
# R2 score correspond to random state  44 is 0.5166108327179095
# R2 score correspond to random state  44 is 0.7343480222765753
# R2 score correspond to random state  45 is 0.7461553892771002
# R2 score correspond to random state  45 is 0.8405764292564516
# R2 score correspond to random state  45 is 0.5816463765176312
# R2 score correspond to random state  45 is 0.5385772728506775
# R2 score correspond to random state  45 is 0.7333714294638061
# R2 score correspond to random state  46 is 0.7298732447308482
# R2 score correspond to random state  46 is 0.847547091928736
# R2 score correspond to random state  46 is 0.5486012423148003
# R2 score correspond to random state  46 is 0.5288752640567544
# R2 score correspond to random state  46 is 0.7390740128447332
# R2 score correspond to random state  47 is 0.7281151957904604
# R2 score correspond to random state  47 is 0.8446301020703688
# R2 score correspond to random state  47 is 0.5748429990418031
# R2 score correspond to random state  47 is 0.5308471745763521
# R2 score correspond to random state  47 is 0.7437475987885337
# R2 score correspond to random state  48 is 0.7205384303472291
# R2 score correspond to random state  48 is 0.8430779228324894
# R2 score correspond to random state  48 is 0.5560822767118399
# R2 score correspond to random state  48 is 0.5267175125701582
# R2 score correspond to random state  48 is 0.7373988323479885
# R2 score correspond to random state  49 is 0.7342638157717573
# R2 score correspond to random state  49 is 0.8456206673126881
# R2 score correspond to random state  49 is 0.545821705328339
# R2 score correspond to random state  49 is 0.5264498099495287
# R2 score correspond to random state  49 is 0.7418688003066963
# R2 score correspond to random state  50 is 0.7476227671587978
# R2 score correspond to random state  50 is 0.8482942577434498
# R2 score correspond to random state  50 is 0.564346035941587
# R2 score correspond to random state  50 is 0.5289494133238155
# R2 score correspond to random state  50 is 0.7400060807207014
# R2 score correspond to random state  51 is 0.7343177016324259
# R2 score correspond to random state  51 is 0.8430053824495459
# R2 score correspond to random state  51 is 0.5597916842055185
# R2 score correspond to random state  51 is 0.5276889579161476
# R2 score correspond to random state  51 is 0.7286926790991108
# R2 score correspond to random state  52 is 0.7360307190376588
# R2 score correspond to random state  52 is 0.8417937249614633
# R2 score correspond to random state  52 is 0.5771577828014381
# R2 score correspond to random state  52 is 0.5293465905218756
# R2 score correspond to random state  52 is 0.7359155131229747
# R2 score correspond to random state  53 is 0.7584406325564996
# R2 score correspond to random state  53 is 0.8461852103765356
# R2 score correspond to random state  53 is 0.5538580025814299
# R2 score correspond to random state  53 is 0.5288149552160579
# R2 score correspond to random state  53 is 0.7402990827925611
# R2 score correspond to random state  54 is 0.731750626766152
# R2 score correspond to random state  54 is 0.8431837981805055
# R2 score correspond to random state  54 is 0.5566914561088673
# R2 score correspond to random state  54 is 0.520227904949184
# R2 score correspond to random state  54 is 0.7281839669276883
# R2 score correspond to random state  55 is 0.7408428630020488
# R2 score correspond to random state  55 is 0.8442040026069058
# R2 score correspond to random state  55 is 0.5614297139050399
# R2 score correspond to random state  55 is 0.5206659124952726
# R2 score correspond to random state  55 is 0.7320522910680842
# R2 score correspond to random state  56 is 0.7366449044198076
# R2 score correspond to random state  56 is 0.8416796876612485
# R2 score correspond to random state  56 is 0.5526736360221324
# R2 score correspond to random state  56 is 0.5325451176059213
# R2 score correspond to random state  56 is 0.7433502121228605
# R2 score correspond to random state  57 is 0.746456878898256
# R2 score correspond to random state  57 is 0.8437643548825047
# R2 score correspond to random state  57 is 0.5794907267739038
# R2 score correspond to random state  57 is 0.535131620913075
# R2 score correspond to random state  57 is 0.7471695791264029
# R2 score correspond to random state  58 is 0.7136194059309686
# R2 score correspond to random state  58 is 0.83871743359096
# R2 score correspond to random state  58 is 0.5503338268287001
# R2 score correspond to random state  58 is 0.5239490449226739
# R2 score correspond to random state  58 is 0.7251095305515807
# R2 score correspond to random state  59 is 0.7176797700380994
# R2 score correspond to random state  59 is 0.8410865449564371
# R2 score correspond to random state  59 is 0.5685314019971179
# R2 score correspond to random state  59 is 0.5228827936301942
# R2 score correspond to random state  59 is 0.733225343673648
# R2 score correspond to random state  60 is 0.7459594746094392
# R2 score correspond to random state  60 is 0.8408366043712517
# R2 score correspond to random state  60 is 0.5595319935905361
# R2 score correspond to random state  60 is 0.5410909427197634
# R2 score correspond to random state  60 is 0.740786399677734
# R2 score correspond to random state  61 is 0.7323047627031829
# R2 score correspond to random state  61 is 0.8454885016607018
# R2 score correspond to random state  61 is 0.5684117037324592
# R2 score correspond to random state  61 is 0.5316524666240523
# R2 score correspond to random state  61 is 0.7414222627450597
# R2 score correspond to random state  62 is 0.7288639591649341
# R2 score correspond to random state  62 is 0.8385480616044819
# R2 score correspond to random state  62 is 0.5578340695893306
# R2 score correspond to random state  62 is 0.5279201019410411
# R2 score correspond to random state  62 is 0.7385732083236749
# R2 score correspond to random state  63 is 0.7426627022313463
# R2 score correspond to random state  63 is 0.8486799727550112
# R2 score correspond to random state  63 is 0.5682916105930844
# R2 score correspond to random state  63 is 0.5330428438755228
# R2 score correspond to random state  63 is 0.7368414713106983
# R2 score correspond to random state  64 is 0.7550779994314727
# R2 score correspond to random state  64 is 0.8469637518051094
# R2 score correspond to random state  64 is 0.5713925524581671
# R2 score correspond to random state  64 is 0.5349163372586986
# R2 score correspond to random state  64 is 0.7425424308984229
# R2 score correspond to random state  65 is 0.7372216244954767
# R2 score correspond to random state  65 is 0.8473676558352636
# R2 score correspond to random state  65 is 0.5611181882880582
# R2 score correspond to random state  65 is 0.5214785865709193
# R2 score correspond to random state  65 is 0.7397313059598492
# R2 score correspond to random state  66 is 0.7336211863574928
# R2 score correspond to random state  66 is 0.8323145699413041
# R2 score correspond to random state  66 is 0.574017592898856
# R2 score correspond to random state  66 is 0.5303587979131426
# R2 score correspond to random state  66 is 0.7287349164020238
# R2 score correspond to random state  67 is 0.7201406559130662
# R2 score correspond to random state  67 is 0.8411347133455016
# R2 score correspond to random state  67 is 0.5569328741051602
# R2 score correspond to random state  67 is 0.5313056738171557
# R2 score correspond to random state  67 is 0.735575529582044
# R2 score correspond to random state  68 is 0.7415885095053893
# R2 score correspond to random state  68 is 0.8358875310138362
# R2 score correspond to random state  68 is 0.5482470960523498
# R2 score correspond to random state  68 is 0.5315114976831754
# R2 score correspond to random state  68 is 0.7345099960065238
# R2 score correspond to random state  69 is 0.7449099852790286
# R2 score correspond to random state  69 is 0.8360366662054652
# R2 score correspond to random state  69 is 0.5493656991997775
# R2 score correspond to random state  69 is 0.5258185738809658
# R2 score correspond to random state  69 is 0.7343106296528914
# R2 score correspond to random state  70 is 0.7475946685831458
# R2 score correspond to random state  70 is 0.8423428795301613
# R2 score correspond to random state  70 is 0.560174289571394
# R2 score correspond to random state  70 is 0.5295438092905752
# R2 score correspond to random state  70 is 0.7404724404801244
# R2 score correspond to random state  71 is 0.7428002207478608
# R2 score correspond to random state  71 is 0.8408529414360181
# R2 score correspond to random state  71 is 0.5570231848158728
# R2 score correspond to random state  71 is 0.5210964387935163
# R2 score correspond to random state  71 is 0.7322452429146584
# R2 score correspond to random state  72 is 0.7301308505330455
# R2 score correspond to random state  72 is 0.8442709437573945
# R2 score correspond to random state  72 is 0.5616973203153834
# R2 score correspond to random state  72 is 0.5279510482933578
# R2 score correspond to random state  72 is 0.7347996679364216
# R2 score correspond to random state  73 is 0.7330647723109851
# R2 score correspond to random state  73 is 0.8417004548216572
# R2 score correspond to random state  73 is 0.5646809723473196
# R2 score correspond to random state  73 is 0.521343114623376
# R2 score correspond to random state  73 is 0.7374246001695364
# R2 score correspond to random state  74 is 0.7344764862059727
# R2 score correspond to random state  74 is 0.836349017742889
# R2 score correspond to random state  74 is 0.548726739912611
# R2 score correspond to random state  74 is 0.5270454802716606
# R2 score correspond to random state  74 is 0.7339276326317257
# R2 score correspond to random state  75 is 0.7416995443747695
# R2 score correspond to random state  75 is 0.8458820671202806
# R2 score correspond to random state  75 is 0.5636525721893899
# R2 score correspond to random state  75 is 0.5428339522019643
# R2 score correspond to random state  75 is 0.7414455908661038
# R2 score correspond to random state  76 is 0.7384215501033491
# R2 score correspond to random state  76 is 0.8449098808895025
# R2 score correspond to random state  76 is 0.5631959431121304
# R2 score correspond to random state  76 is 0.5376197750040611
# R2 score correspond to random state  76 is 0.74234615880453
# R2 score correspond to random state  77 is 0.7298025332561968
# R2 score correspond to random state  77 is 0.8417572921257516
# R2 score correspond to random state  77 is 0.5377218543848252
# R2 score correspond to random state  77 is 0.5197665873550665
# R2 score correspond to random state  77 is 0.7334159135453644
# R2 score correspond to random state  78 is 0.754822947892501
# R2 score correspond to random state  78 is 0.834713204406153
# R2 score correspond to random state  78 is 0.540792834464334
# R2 score correspond to random state  78 is 0.5178161411948916
# R2 score correspond to random state  78 is 0.7305863776372508
# R2 score correspond to random state  79 is 0.7441930357204458
# R2 score correspond to random state  79 is 0.8437005841759694
# R2 score correspond to random state  79 is 0.544204962325417
# R2 score correspond to random state  79 is 0.5197938388206267
# R2 score correspond to random state  79 is 0.7335098868828547
# R2 score correspond to random state  80 is 0.7424813076095252
# R2 score correspond to random state  80 is 0.8500661139863255
# R2 score correspond to random state  80 is 0.5485677188167362
# R2 score correspond to random state  80 is 0.5251227364453874
# R2 score correspond to random state  80 is 0.7381790268577948
# R2 score correspond to random state  81 is 0.7389186889315023
# R2 score correspond to random state  81 is 0.842062711040326
# R2 score correspond to random state  81 is 0.5647146089937667
# R2 score correspond to random state  81 is 0.5362367633765177
# R2 score correspond to random state  81 is 0.7361271561267192
# R2 score correspond to random state  82 is 0.7303377095304071
# R2 score correspond to random state  82 is 0.8412510228701863
# R2 score correspond to random state  82 is 0.5413374487581435
# R2 score correspond to random state  82 is 0.5264516215817496
# R2 score correspond to random state  82 is 0.7361916413028837
# R2 score correspond to random state  83 is 0.7524882175836746
# R2 score correspond to random state  83 is 0.838978693677098
# R2 score correspond to random state  83 is 0.5624765381192813
# R2 score correspond to random state  83 is 0.5277195685131892
# R2 score correspond to random state  83 is 0.7355280985180541
# R2 score correspond to random state  84 is 0.7300532121470454
# R2 score correspond to random state  84 is 0.8404924349959606
# R2 score correspond to random state  84 is 0.5374559650183264
# R2 score correspond to random state  84 is 0.5161526157377947
# R2 score correspond to random state  84 is 0.7375167711853778
# R2 score correspond to random state  85 is 0.7548882480994769
# R2 score correspond to random state  85 is 0.8432406843023057
# R2 score correspond to random state  85 is 0.5685027608504973
# R2 score correspond to random state  85 is 0.5292342496441274
# R2 score correspond to random state  85 is 0.7346281866127191
# R2 score correspond to random state  86 is 0.7406968716615892
# R2 score correspond to random state  86 is 0.8429588927901598
# R2 score correspond to random state  86 is 0.5723301011648043
# R2 score correspond to random state  86 is 0.5326507549472872
# R2 score correspond to random state  86 is 0.7346118398549173
# R2 score correspond to random state  87 is 0.7319283737862075
# R2 score correspond to random state  87 is 0.8433423048708215
# R2 score correspond to random state  87 is 0.5542364762273757
# R2 score correspond to random state  87 is 0.5312282036999881
# R2 score correspond to random state  87 is 0.7380310546391469
# R2 score correspond to random state  88 is 0.7410375295701297
# R2 score correspond to random state  88 is 0.8450093340881965
# R2 score correspond to random state  88 is 0.5544507277526898
# R2 score correspond to random state  88 is 0.5395415753616473
# R2 score correspond to random state  88 is 0.7414575599742522
# R2 score correspond to random state  89 is 0.7241056423182552
# R2 score correspond to random state  89 is 0.8368385143544516
# R2 score correspond to random state  89 is 0.5645943206817355
# R2 score correspond to random state  89 is 0.5315894980397307
# R2 score correspond to random state  89 is 0.7511983814364057
#
#
#
#
# max R2 score correspond to random state  80 is 0.8500661139863255 and model is KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
#Checking the best parameter for prediction of KNeighborsRegressor Algo using GridSearchCV
train_x,test_x,train_y,test_y = train_test_split(x,y,random_state = 80,test_size = 0.33)
KN = KNeighborsRegressor()
parameters={'n_neighbors' : range(1,30)}
gridsearch=GridSearchCV(LA,parameters)
gridsearch.fit(train_x,train_y)
gridsearch.best_params_
# Out:
# {'n_neighbors': 2}

# %%
KNN = KNeighborsRegressor(n_neighbors=2)
KNN.fit(train_x,train_y)
pred = KNN.predict(test_x)
r2_sc = r2_score(test_y,pred)
print("R2 Score :",r2_sc*100)
# Out:
# R2 Score : 86.81110301059822

# %%
print('Mean Absolute Error: ', mean_absolute_error(test_y,pred))
print('Mean squared Error: ', mean_squared_error(test_y,pred))
print('Root Mean Absolute Error: ', np.sqrt(mean_absolute_error(test_y,pred)))
# Out:
# Mean Absolute Error:  0.09554201244813278
# Mean squared Error:  0.019070146092669434
# Root Mean Absolute Error:  0.30909870987782007

# %%
#checking the diff between actual and predicted value using graph
plt.scatter(x=test_y,y=pred)
plt.xlabel('Y_Test')
plt.ylabel('Predicted_Y')
# Out:
# Text(0, 0.5, 'Predicted_Y')

# %% [markdown]
# As above graph shown that it is predicting near to tha actual value and RMSE error is very less

# %%
#importing library for classification prediction
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

# %%
#assign the value of x and y for training and testing phase
x_c = df.drop(columns=['region','Date'])
y_c = df[["region"]]
print(x_c.shape)
print(y_c.shape)
# Out:
# (17525, 12)
# (17525, 1)

# %%
#Standardize the value of x so that mean will 0 and SD will become 1 , and make the data as normal distributed
sc = StandardScaler()
sc.fit_transform(x_c)
x_c = pd.DataFrame(x_c,columns=x_c.columns)

# %% [markdown]
# now we are taking region as output variable and try to prediction using classification method

# %%
#Now by using multiple Algorithms we are calculating the best Algo which suit best for our data set 

model = [DecisionTreeClassifier(),KNeighborsClassifier()]
max_accuracy_score = 0
for r_state in range(40,90):
    train_xc,test_xc,train_yc,test_yc = train_test_split(x_c,y_c,random_state = r_state,test_size = 0.33)
    for i_c in model:
        i_c.fit(train_xc,train_yc)
        pre_c = i_c.predict(test_xc)
        ac_score = accuracy_score(test_yc,pre_c)
        print("accuracy score correspond to random state " ,r_state ,"is", ac_score)
        if ac_score> max_accuracy_score:
            max_accuracy_score=ac_score
            final_state = r_state
            final_model = i_c
            
print()
print()
print()
print()

print("max accuracy score correspond to random state " ,final_state , "is" , max_accuracy_score ,"and model is",final_model)
# Out:
# accuracy score correspond to random state  40 is 0.7792185338865837
# accuracy score correspond to random state  40 is 0.7930497925311203
# accuracy score correspond to random state  41 is 0.780774550484094
# accuracy score correspond to random state  41 is 0.7942600276625172
# accuracy score correspond to random state  42 is 0.7830221300138313
# accuracy score correspond to random state  42 is 0.7921853388658368
# accuracy score correspond to random state  43 is 0.7769709543568465
# accuracy score correspond to random state  43 is 0.7956431535269709
# accuracy score correspond to random state  44 is 0.7788727524204703
# accuracy score correspond to random state  44 is 0.7978907330567082
# accuracy score correspond to random state  45 is 0.7773167358229599
# accuracy score correspond to random state  45 is 0.7975449515905948
# accuracy score correspond to random state  46 is 0.7880359612724758
# accuracy score correspond to random state  46 is 0.7977178423236515
# accuracy score correspond to random state  47 is 0.790283540802213
# accuracy score correspond to random state  47 is 0.7918395573997233
# accuracy score correspond to random state  48 is 0.7802558782849239
# accuracy score correspond to random state  48 is 0.7949515905947441
# accuracy score correspond to random state  49 is 0.7691908713692946
# accuracy score correspond to random state  49 is 0.801002766251729
# accuracy score correspond to random state  50 is 0.7811203319502075
# accuracy score correspond to random state  50 is 0.7942600276625172
# accuracy score correspond to random state  51 is 0.781984785615491
# accuracy score correspond to random state  51 is 0.8054979253112033
# accuracy score correspond to random state  52 is 0.7892461964038727
# accuracy score correspond to random state  52 is 0.7939142461964038
# accuracy score correspond to random state  53 is 0.789073305670816
# accuracy score correspond to random state  53 is 0.801002766251729
# accuracy score correspond to random state  54 is 0.7723029045643154
# accuracy score correspond to random state  54 is 0.8067081604426003
# accuracy score correspond to random state  55 is 0.7850968188105117
# accuracy score correspond to random state  55 is 0.7925311203319502
# accuracy score correspond to random state  56 is 0.7691908713692946
# accuracy score correspond to random state  56 is 0.7899377593360996
# accuracy score correspond to random state  57 is 0.771957123098202
# accuracy score correspond to random state  57 is 0.7906293222683264
# accuracy score correspond to random state  58 is 0.77783540802213
# accuracy score correspond to random state  58 is 0.7999654218533887
# accuracy score correspond to random state  59 is 0.7880359612724758
# accuracy score correspond to random state  59 is 0.8022130013831259
# accuracy score correspond to random state  60 is 0.7828492392807745
# accuracy score correspond to random state  60 is 0.7968533886583679
# accuracy score correspond to random state  61 is 0.7852697095435685
# accuracy score correspond to random state  61 is 0.8008298755186722
# accuracy score correspond to random state  62 is 0.7835408022130014
# accuracy score correspond to random state  62 is 0.7965076071922544
# accuracy score correspond to random state  63 is 0.7894190871369294
# accuracy score correspond to random state  63 is 0.7971991701244814
# accuracy score correspond to random state  64 is 0.7835408022130014
# accuracy score correspond to random state  64 is 0.803941908713693
# accuracy score correspond to random state  65 is 0.770746887966805
# accuracy score correspond to random state  65 is 0.7878630705394191
# accuracy score correspond to random state  66 is 0.784923928077455
# accuracy score correspond to random state  66 is 0.7977178423236515
# accuracy score correspond to random state  67 is 0.7797372060857538
# accuracy score correspond to random state  67 is 0.7868257261410788
# accuracy score correspond to random state  68 is 0.7809474412171508
# accuracy score correspond to random state  68 is 0.8048063623789765
# accuracy score correspond to random state  69 is 0.7806016597510373
# accuracy score correspond to random state  69 is 0.796161825726141
# accuracy score correspond to random state  70 is 0.7823305670816044
# accuracy score correspond to random state  70 is 0.7965076071922544
# accuracy score correspond to random state  71 is 0.781984785615491
# accuracy score correspond to random state  71 is 0.7921853388658368
# accuracy score correspond to random state  72 is 0.7785269709543569
# accuracy score correspond to random state  72 is 0.7968533886583679
# accuracy score correspond to random state  73 is 0.7795643153526971
# accuracy score correspond to random state  73 is 0.7889004149377593
# accuracy score correspond to random state  74 is 0.7850968188105117
# accuracy score correspond to random state  74 is 0.8065352697095436
# accuracy score correspond to random state  75 is 0.7814661134163209
# accuracy score correspond to random state  75 is 0.8094744121715076
# accuracy score correspond to random state  76 is 0.780774550484094
# accuracy score correspond to random state  76 is 0.8120677731673582
# accuracy score correspond to random state  77 is 0.7921853388658368
# accuracy score correspond to random state  77 is 0.8030774550484094
# accuracy score correspond to random state  78 is 0.7797372060857538
# accuracy score correspond to random state  78 is 0.7927040110650069
# accuracy score correspond to random state  79 is 0.7850968188105117
# accuracy score correspond to random state  79 is 0.8034232365145229
# accuracy score correspond to random state  80 is 0.7876901798063624
# accuracy score correspond to random state  80 is 0.8015214384508991
# accuracy score correspond to random state  81 is 0.7759336099585062
# accuracy score correspond to random state  81 is 0.7873443983402489
# accuracy score correspond to random state  82 is 0.7984094052558783
# accuracy score correspond to random state  82 is 0.7930497925311203
# accuracy score correspond to random state  83 is 0.7835408022130014
# accuracy score correspond to random state  83 is 0.7973720608575381
# accuracy score correspond to random state  84 is 0.7911479944674965
# accuracy score correspond to random state  84 is 0.8034232365145229
# accuracy score correspond to random state  85 is 0.7785269709543569
# accuracy score correspond to random state  85 is 0.7959889349930843
# accuracy score correspond to random state  86 is 0.779045643153527
# accuracy score correspond to random state  86 is 0.8006569847856155
# accuracy score correspond to random state  87 is 0.789073305670816
# accuracy score correspond to random state  87 is 0.7982365145228216
# accuracy score correspond to random state  88 is 0.7859612724757953
# accuracy score correspond to random state  88 is 0.799792531120332
# accuracy score correspond to random state  89 is 0.7868257261410788
# accuracy score correspond to random state  89 is 0.7973720608575381
#
#
#
#
# max accuracy score correspond to random state  76 is 0.8120677731673582 and model is KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
#Checking the best parameter for prediction of KNeighborsClassifier Algo using GridSearchCV
train_xc,test_xc,train_yc,test_yc = train_test_split(x_c,y_c,random_state = 76,test_size = 0.33)
KNC = KNeighborsClassifier()
parameters={'n_neighbors' : range(1,30)}
gridsearch=GridSearchCV(KNC,parameters)
gridsearch.fit(train_xc,train_yc)
gridsearch.best_params_
# Out:
# {'n_neighbors': 1}

# %%
KNC = KNeighborsClassifier(n_neighbors=1)
KNC.fit(train_xc,train_yc)
predc = KNC.predict(test_xc)
acu_score = accuracy_score(test_yc,predc)
print("Accuracy Score :",acu_score*100)
# Out:
# Accuracy Score : 85.56362378976486

# %%
#Calculating the scores of different parameters
score = cross_val_score(KNC,x_c,y_c,cv = 100,scoring='accuracy').mean()
print('Cross_val_score : ', score*100)
print('Mean Score      : ' , score.mean()*100)
print('STD score       : ' , score.std())
# Out:
# Cross_val_score :  80.90415584415584
# Mean Score      :  80.90415584415584
# STD score       :  0.0

# %%
pred_prob = KNC.predict_proba(test_xc)[:,1]
pred_prob
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
fpr,tpr,thresholds = roc_curve(test_yc,pred_prob,pos_label=True)

# %%
print(fpr)
print("\n")
print(tpr)
print("\n")
print(thresholds)
# Out:
# [0.         0.00423355 1.        ]
#
#
# [0.         0.85217391 1.        ]
#
#
# [2. 1. 0.]

# %%
#Plotting the graph which tells us about the area under curve , more the area under curve more will be the better prediction

plt.plot([0,1],[1,0],'k--')
plt.plot(fpr,tpr,label = 'KNeighborsClassifier')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('KNeighborsClassifier')
plt.show()

# %% [markdown]
# As from this data set we have following conclusion:
#     - taking price as y variable is predicting well for this model as comapared to region
#     - also r2 score value is also greater then accuracy score

# %%
#save the model 
joblib.dump(KNN, 'Project_8.obj')
# Out:
# ['Project_8.obj']
